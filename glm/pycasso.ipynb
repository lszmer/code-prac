# %%
import numpy as np
from pycasso.core import fit

# Generate some synthetic data for demonstration
np.random.seed(42)
n_samples, n_features = 100, 20
X = np.random.randn(n_samples, n_features)
true_coef = np.array([1.5, -2.0, 0.0, 0.8, 0.0, 0.0, -1.2, 0.0, 0.5] + [0.0] * (n_features - 9))
linear_predictor = X @ true_coef + np.random.normal(0, 0.5, n_samples)
probabilities = 1 / (1 + np.exp(-linear_predictor))
y = (probabilities > 0.5).astype(int)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 from pycasso.core import fit
#       4 # Generate some synthetic data for demonstration
#       5 np.random.seed(42)
#
# File /opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/__init__.py:22
#      18     print(r"Version: "+open(os.path.join(current_file, r'./VERSION')).read().strip())
#      20 __all__ = ["core"]
# ---> 22 from .core import Solver
#
# File /opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/core.py:34
#      30   return lib
#      33 # load the PICASSO library globally
# ---> 34 _PICASSO_LIB = _load_lib()
#      37 class Solver:
#      38   """
#      39     The PICASSO Solver For GLM.
#      40
#    (...)     64     :param verbose: Tracing information is disabled if `verbose = False`. The default value is `False`.
#      65     """
#
# File /opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/core.py:29, in _load_lib()
#      26 if not lib_path:
#      27   PycassoError(
#      28       "Can not find picasso Library. Please install pycasso correctly.")
# ---> 29 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#      30 return lib
#
# File /opt/miniconda3/envs/practiceenv/lib/python3.13/ctypes/__init__.py:471, in LibraryLoader.LoadLibrary(self, name)
#     470 def LoadLibrary(self, name):
# --> 471     return self._dlltype(name)
#
# File /opt/miniconda3/envs/practiceenv/lib/python3.13/ctypes/__init__.py:390, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     387 self._FuncPtr = _FuncPtr
#     389 if handle is None:
# --> 390     self._handle = _dlopen(self._name, mode)
#     391 else:
#     392     self._handle = handle
#
# OSError: dlopen(/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/./lib/libpicasso.so, 0x0006): tried: '/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/./lib/libpicasso.so' (not a mach-o file), '/System/Volumes/Preboot/Cryptexes/OS/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/./lib/libpicasso.so' (no such file), '/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/./lib/libpicasso.so' (not a mach-o file), '/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/lib/libpicasso.so' (not a mach-o file), '/System/Volumes/Preboot/Cryptexes/OS/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/lib/libpicasso.so' (no such file), '/opt/miniconda3/envs/practiceenv/lib/python3.13/site-packages/pycasso/lib/libpicasso.so' (not a mach-o file)
