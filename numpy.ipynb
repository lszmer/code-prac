# %%
import numpy as np

# %%
np.arange(1, 10, 2)
rand = np.random.randint(1, 10, 4)
rand.flatten()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 np.arange(1, 10, 2)
# ----> 2 rand = np.random.randint(1, 10, 2, 2)
#       3 rand.flatten()
#
# File numpy/random/mtrand.pyx:775, in numpy.random.mtrand.RandomState.randint()
#
# TypeError: Cannot interpret '2' as a data type
